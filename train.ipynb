# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.model_selection import GridSearchCV

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Data Cleansing and formatting
# - Deal with Null's by:
#    - On Age, by filling with mean
#    - On Embarked, by erasing them because small amount
#    - On Cabin, we give the nulls a category

# %%
# check for null values
df_train.isnull().sum()
# We drop Cabin
df_train.drop(['Cabin'], axis=1, inplace=True)
# We transform the empty values into a new category U
#df_train['Cabin'].fillna('U', inplace=True)
#df_train['Cabin'] = df_train['Cabin'].apply(lambda x: 0 if x[0]=='A' else (1 if x[0]=='U' else 2))

# Depending on the distribution of Age we will replace the NaN's with the median or the mean
# it is normal so we use the mean
df_train['Age'].fillna(df_train['Age'].mean(), inplace=True)

# Embarked is a categorical variable with only two nan's, it is safe to drop the rows
df_train.dropna(inplace=True, axis=0, subset=['Embarked'])

# %% [markdown]
# ### Feature Engineering
# - Adjusgt non-ordinal categorical features to one hot encoding
# - Create a feature of alone/ not alone using SibSp and Parch
# - Create a feature child or not child with age

# %%
# Encode embarked into 3 columns
df_train = pd.get_dummies(df_train, columns = ['Embarked', 'Pclass'])

# Change male and Female into 1 and 0
df_train['Sex'] = df_train['Sex'].apply(lambda x: 1 if x=='male' else 0)

# %%
# create feature alone or not alone
df_train['Alone'] = df_train['SibSp'] + df_train['Parch']
df_train['Alone'] = df_train['Alone'].apply(lambda x: 1 if x >=1 else 0)

# %%
# create feature child or not
df_train['Childornot'] = df_train['Age'].apply(lambda x: 1 if x < 15 else 0)

# %% [markdown]
# ### DATA exploration
# - Correlations
# - Chi-squared dependency test

# %%
corr = df_train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col0 {
#             background-color:  #b40426;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col1 {
#             background-color:  #afcafc;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col2 {
#             background-color:  #bad0f8;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col3 {
#             background-color:  #bad0f8;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col4 {
#             background-color:  #6788ee;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col5 {
#             background-color:  #7a9df8;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col6 {
#             background-color:  #9ebeff;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col7 {
#             background-color:  #ccd9ed;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col8 {
#             background-color:  #a2c1ff;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col9 {
#             background-color:  #cfdaea;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col10 {
#             background-color:  #c1d4f4;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col11 {
#             background-color:  #b3cdfb;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col12 {
#             background-color:  #b5cdfa;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col13 {
#             background-color:  #779af7;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row0_col14 {
#             background-color:  #aec9fc;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col0 {
#             background-color:  #4961d2;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col1 {
#             background-color:  #b40426;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col2 {
#             background-color:  #3b4cc0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col3 {
#             background-color:  #a3c2fe;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col4 {
#             background-color:  #6e90f2;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col5 {
#             background-color:  #92b4fe;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col6 {
#             background-color:  #d5dbe5;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col7 {
#             background-color:  #e5d8d1;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col8 {
#             background-color:  #abc8fd;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col9 {
#             background-color:  #b1cbfc;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col10 {
#             background-color:  #ead4c8;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col11 {
#             background-color:  #c7d7f0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col12 {
#             background-color:  #779af7;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col13 {
#             background-color:  #bed2f6;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row1_col14 {
#             background-color:  #cdd9ec;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col0 {
#             background-color:  #5875e1;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col1 {
#             background-color:  #3b4cc0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col2 {
#             background-color:  #b40426;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col3 {
#             background-color:  #c6d6f1;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col4 {
#             background-color:  #5875e1;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col5 {
#             background-color:  #3b4cc0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col6 {
#             background-color:  #6f92f3;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col7 {
#             background-color:  #bed2f6;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col8 {
#             background-color:  #98b9ff;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col9 {
#             background-color:  #dedcdb;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col10 {
#             background-color:  #a7c5fe;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col11 {
#             background-color:  #a5c3fe;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col12 {
#             background-color:  #d4dbe6;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col13 {
#             background-color:  #3b4cc0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row2_col14 {
#             background-color:  #9fbfff;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col0 {
#             background-color:  #5470de;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col1 {
#             background-color:  #9fbfff;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col2 {
#             background-color:  #c3d5f4;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col3 {
#             background-color:  #b40426;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col4 {
#             background-color:  #3b4cc0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col5 {
#             background-color:  #4b64d5;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col6 {
#             background-color:  #b1cbfc;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col7 {
#             background-color:  #d2dbe8;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col8 {
#             background-color:  #a7c5fe;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col9 {
#             background-color:  #c9d7f0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col10 {
#             background-color:  #efcfbf;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col11 {
#             background-color:  #b6cefa;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col12 {
#             background-color:  #80a3fa;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col13 {
#             background-color:  #5977e3;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row3_col14 {
#             background-color:  #3b4cc0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col0 {
#             background-color:  #3b4cc0;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col1 {
#             background-color:  #a9c6fd;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col2 {
#             background-color:  #96b7ff;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col3 {
#             background-color:  #81a4fb;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col4 {
#             background-color:  #b40426;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col5 {
#             background-color:  #e4d9d2;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col6 {
#             background-color:  #c1d4f4;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col7 {
#             background-color:  #c1d4f4;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col8 {
#             background-color:  #a3c2fe;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col9 {
#             background-color:  #d7dce3;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col10 {
#             background-color:  #b1cbfc;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col11 {
#             background-color:  #a7c5fe;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col12 {
#             background-color:  #ccd9ed;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col13 {
#             background-color:  #f7b396;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row4_col14 {
#             background-color:  #f1ccb8;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807row5_col0 {
#             background-color:  #4a63d3;
#         }    #T_dd93d3dc_785a_11ea_afae_f894c24ff807ro

# %% [markdown]
# ### Data Transformation
# - Normalize the data. Subtract mean and divide by std

# %%
df_train[['Age', 'SibSp', 'Parch', 'Fare']] = preprocessing.scale(df_train[['Age', 'SibSp', 'Parch', 'Fare']])
# Out:
# c:\users\rammirata001\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Train

# %%
train = df_train[['Sex', 'Childornot', 'Fare', 'Embarked_C', 'Embarked_S', 
                 'Pclass_1', 'Pclass_2', 'Pclass_3', 'Alone']]

test = df_train['Survived']

X_train, X_test, y_train, y_test = train_test_split(train, test, test_size=0.20, random_state=42)

# %%
parameters = {'n_estimators': [100,200,300], 'max_depth': [3, 4, 5, 6, 7, 8], 'min_samples_leaf': [3, 5, 10, 15, 20]}
clf = GridSearchCV(RandomForestClassifier(), parameters, cv=5, scoring='f1')
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83       109
#            1       0.73      0.77      0.75        69
#
#    micro avg       0.80      0.80      0.80       178
#    macro avg       0.79      0.79      0.79       178
# weighted avg       0.80      0.80      0.80       178

# %%
#print("SVM metrics")
#clf_1 = SVC().fit(X_train, y_train)
#y_pred = clf_1.predict(X_test)
#print(classification_report(y_test, y_pred))

#print("Log reg metrics")
#clf_2 = LogisticRegression(random_state=0).fit(X_train, y_train)
#y_pred = clf_2.predict(X_test)
#print(classification_report(y_test, y_pred))

#print("NN metrics")
#clf_3 = MLPClassifier(hidden_layer_sizes=15, max_iter=200).fit(X_train, y_train)
#y_pred = clf_3.predict(X_test)
#print(classification_report(y_test, y_pred))

print("RF metrics")
clf_4 = RandomForestClassifier(n_estimators = 200, max_depth=5, min_samples_leaf=5).fit(X_train, y_train)
y_pred = clf_4.predict(X_test)
print(classification_report(y_test, y_pred))

#print("Ensemble metrics")
#clf_5 = VotingClassifier(estimators=[('SVM', clf_1), ('LR', clf_2), ('NN', clf_3), ('RF', clf_4)], voting='hard')
#clf_5 = clf_5.fit(X_train, y_train)
#y_pred = clf_5.predict(X_test)
#print(classification_report(y_test, y_pred))
# Out:
# RF metrics
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86       109
#            1       0.80      0.71      0.75        69
#
#    micro avg       0.82      0.82      0.82       178
#    macro avg       0.82      0.80      0.81       178
# weighted avg       0.82      0.82      0.82       178

# %% [markdown]
# ### Predict

# %%
df_test = pd.read_csv('test.csv')

# clearly we wont be able to use the Cabin column, it has too many NaN values
df_test.drop(['Cabin'], axis=1, inplace=True)

# Depending on the distribution of Age we will replace the NaN's with the median or the mean
# it is normal so we use the mean
df_test['Age'].fillna(df_train['Age'].mean(), inplace=True)
df_test['Fare'].fillna(df_train['Fare'].mean(), inplace=True)

# Embarked is a categorical variable with only two nan's, it is safe to drop the rows
df_test.dropna(inplace=True, axis=0, subset=['Embarked'])

# Encode embarked into 3 columns
df_test = pd.get_dummies(df_test, columns = ['Embarked'])

# Encode Pclass into 3 columns
df_test = pd.get_dummies(df_test, columns=['Pclass'])

# Change male and Female into 1 and 0
df_test['Sex'] = df_test['Sex'].apply(lambda x: 1 if x=='male' else 0)

df_test['Alone'] = df_test['SibSp'] + df_train['Parch']
df_test['Alone'] = df_test['Alone'].apply(lambda x: 1 if x >=1 else 0)

# create feature child or not
df_test['Childornot'] = df_test['Age'].apply(lambda x: 1 if x < 15 else 0)

df_test[['Age', 'SibSp', 'Parch', 'Fare']] = preprocessing.scale(df_test[['Age', 'SibSp', 'Parch', 'Fare']])

test = df_test[['Sex', 'Childornot', 'Fare', 'Embarked_C', 'Embarked_S', 
                 'Pclass_1','Pclass_3', 'Alone']]

y_pred = clf_4.predict(test)

df_test['Survived'] = y_pred

df_test[['PassengerId', 'Survived']].to_csv('outputs.csv')
# Out:
# c:\users\rammirata001\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:29: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
